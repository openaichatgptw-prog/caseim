# %%
import pandas as pd
from openai import OpenAI
import json
import time

# ============================================================
# 01. Cargar configuración desde JSON
# ============================================================
with open("ConfigClasificador.json", "r", encoding="utf-8") as f:
    config = json.load(f)

API_KEY       = config["OPENAI_API_KEY"]
INPUT_XLSX    = config["INPUT_XLSX"]
OUTPUT_XLSX   = config["OUTPUT_XLSX"]
SHEET_NAME    = config["SHEET_NAME"]
use_cols      = config["USE_COLS"]
SLEEP_SECONDS = config["SLEEP_SECONDS"]
MODEL         = config["MODEL"]

# Inicializar cliente con la API Key del JSON
client = OpenAI(api_key=API_KEY)

# ============================================================
# PROMPTS
# ============================================================
PROMPT_DIRECT = """
Eres un clasificador muy estricto.
Analiza únicamente esta descripción de producto:

"{descripcion}"

Reglas:
1. Devuelve SOLO el JSON plano, sin comentarios ni bloques de código.
2. Para la clave "Marca":
   - Devuelve exactamente lo que aparezca en el texto, en MAYÚSCULA.
   - Si hay varias marcas explícitas, sepáralas con coma.
   - Si no hay marca, devuelve "DESCONOCIDA".
   - No inventes datos irrelevantes (ej: si el texto menciona la marca de un motor por ejemplo motor Perkins en un tractor Massey Ferguson, la marca principal es MASSEY FERGUSON, no PERKINS)
3. Para la clave "Condicion":
   - Devuelve "USADO" si aparecen palabras como "usado", "segunda","reacondicionado","remanufacturado","refurbished","utilizado","segunda mano" o un año que no sea el vigente.
   - Si no aparecen, devuelve "NUEVO".

Responde SOLO en JSON válido con este formato:
{{"Marca": "...", "Condicion": "..."}}
"""

PROMPT_INFER = """
Tengo esta descripción de mercancía: "{descripcion}".

Reglas:
1. Si no hay marca explícita, usa seriales, referencias o modelos
   para INFERIR la marca más probable. (ejemplo: "249D3": CATERPILLAR, "ZX10U-6" : HITACHI, "WA470" : KOMATSU) usa tus datos de entrenamiento de modelos y marcas de maquinaria amarilla
2. Devuelve en MAYÚSCULA.
3. Si hay varias posibles, sepáralas con coma.
4. Si no se puede inferir, responde "DESCONOCIDA".
5. Devuelve SOLO JSON plano, sin bloques de código.

Formato:
{{"Marca_probable": "..."}}
"""

# ============================================================
# FUNCIÓN CLASIFICADORA
# ============================================================
def clasificar_producto(descripcion: str):
    # --- Paso 1: extracción directa ---
    resp = client.responses.create(
        model=MODEL,
        input=PROMPT_DIRECT.format(descripcion=descripcion)
    )
    text = resp.output[0].content[0].text.strip()
    try:
        result = json.loads(text)
        marca = result.get("Marca", "DESCONOCIDA").upper()
        condicion = result.get("Condicion", "NUEVO").upper()
    except:
        print("Error parseando JSON directo. Respuesta:", text)
        marca, condicion = "DESCONOCIDA", "NUEVO"

    # --- Paso 2: inferencia si no hay marca ---
    marca_probable = marca
    if marca == "DESCONOCIDA":
        resp2 = client.responses.create(
            model=MODEL,
            input=PROMPT_INFER.format(descripcion=descripcion)
        )
        text2 = resp2.output[0].content[0].text.strip()
        try:
            result2 = json.loads(text2)
            marca_probable = result2.get("Marca_probable", "DESCONOCIDA").upper()
        except:
            print("Error parseando JSON inferencia. Respuesta:", text2)
            marca_probable = "DESCONOCIDA"

    return marca, marca_probable, condicion

# ============================================================
# PROCESAR TODO EL DF
# ============================================================
marcas, marcas_probables, condiciones = [], [], []

df = pd.read_excel(INPUT_XLSX, sheet_name=SHEET_NAME, usecols=use_cols, engine="openpyxl")
print("Columnas cargadas:", df.columns.tolist())

for i, desc in enumerate(df["Descripción de la mercancía"]):
    marca, marca_prob, condicion = clasificar_producto(desc)
    marcas.append(marca)
    marcas_probables.append(marca_prob)
    condiciones.append(condicion)

    #  Mostrar en consola resultado de la fila
    print(f"\nFila {i+1}:")
    print(f" Descripción: {desc}")
    print(f" Marca: {marca}")
    print(f" Marca probable: {marca_prob}")
    print(f" Condición: {condicion}")
    print("-" * 60)

    if (i+1) % 20 == 0:
        print(f" Procesadas {i+1}/{len(df)} filas...\n")
    time.sleep(SLEEP_SECONDS)

df["Marca"] = marcas
df["Marca_probable"] = marcas_probables
df["Condicion"] = condiciones

# ============================================================
# GUARDAR RESULTADOS
# ============================================================
df.to_excel(OUTPUT_XLSX, index=False)
print("\n Archivo generado:", OUTPUT_XLSX)
# Out:
# Columnas cargadas: ['fila', 'Descripción de la mercancía']
#
# Fila 1:
#  Descripción: DO I-145324 DECLARACION 1 DE 1DESGRAVACION ARANCELARIA DEL 0 %: DECRETO 272 DE 2018  NO REQUIERE DE ACUERDO CON LOS A
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 2:
#  Descripción: Do: 13BOGBU12240048, Nro Pedido  Orden Compra:TIMZ204, Declaracion: 11 Codigo OEA: OEA  MERCANCIA NUEVA Y DE PRIMERA
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 3:
#  Descripción: DO. BUN14034 DECLARACION 1 1FACTURA(S):1200 DCTO DE TRANSPORTE NO. 243406304 , MERCANCIA USADA , LICENCIA DE IMPORTA
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: USADO
# ------------------------------------------------------------
#
# Fila 4:
#  Descripción: DO,00000128 Pedido 500MTD0 D,I, 33026884 Codigo, OEA No, OE0003   FACTURA No, IN000902545 DE FECHA  27-MAR-2024  , Ref
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 5:
#  Descripción: DO,00000134 Pedido 500MTD0 D,I, 33026877 Codigo, OEA No, OE0003   FACTURA No, IN000902568 DE FECHA  27-MAR-2024  , Ref
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 6:
#  Descripción: DO,00000134 Pedido 500MTD0 D,I, 33026879 Codigo, OEA No, OE0003   FACTURA No, IN000902564 DE FECHA  27-MAR-2024  , Ref
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 7:
#  Descripción: DO,00000128 Pedido 500MTD0 D,I, 33026883 Codigo, OEA No, OE0003   FACTURA No, IN000902537 DE FECHA  27-MAR-2024  , Ref
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 8:
#  Descripción: DO,00000134 Pedido 500MTD0 D,I, 33026878 Codigo, OEA No, OE0003   FACTURA No, IN000902570 DE FECHA  27-MAR-2024  , Ref
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 9:
#  Descripción: DO 2796-EIF, PEDIDO 2796-EIF, DECLARACION 1 DE 1; ; MERCANC¿A USADA, A¿O DE FABRICACI¿N: 2015 ; AMPARADA EN LICENCIA DE IMPORTACI¿N NO. LIC-40000175-20250107N DE 07/01/2025 ; VISTO BUENO ICA FITOSANITARIO NO. VIFS-2025-00084 DE 03/01/2025 ; VISTO BUENO ANLA NO. VANLA-25-00115 DE 03/01/2025 (CERTIFICADO DE EMISI¿N POR PRUEBA DIN¿MICA NO. 26754) ; NOS ACOGEMOS A LA DESGRAVACI¿N ARANCELARIA DEL DECRETO NO. 272 DE 13/02/2018 (GRAVAMEN 0%) ; LAS DEM¿S CARRETILLAS AUTOPROPULSADAS ;, FACTURA(S):698917-12540671; 1 UNIDAD 2015 JLG 600AJ 4WD DIESEL ARTICULATING BOOM LIFT / PRODUCTO: CARRETILLA AUTOPROPULSADA / PLATAFORMA ELEVADORA, MARCA: JLG¿, MODELO: 600AJ, REFERENCIA: NO TI ENE, SERIAL: 0300204909, USO O DESTINO: INDUSTRIAL, FUERA DE RED DE CARRETERAS / INFORMACI¿N PLACA PRINCIPAL: MAX. PLATFORM HEIGHT 60 FT, MAX. HORIZONTAL REACH 39.74 FT, UNRESTRICTED RATED CAPACITY 500 LBS, MAXIMUM CAPACITY 5 00 LBS, ELECTRICAL SYSTEMS VOLTAGE 12, RATED GRADABILITY 45% / INFORMACI¿N PLACA MOTOR: DEUTZ¿, MODEL TD 2.9 L4, SERNO 11725395, CODE C4DI50, DISPL 2.925, KW 50,0, HP 67, RPM 2600, MFGDATE 11/2014, FAMILY EDZXL02.9020, MADE I N GERMANY ;
#  Marca: JLG
#  Marca probable: JLG
#  Condición: USADO
# ------------------------------------------------------------
#
# Fila 10:
#  Descripción: DO GRUPO-24772BUN ,Pedido 2024-07511 ,Formato 1 de 1; Factura(s)...0007-3477 28/06/2024;CUMPLE CON REGISTRO DE IMPORTACION NO. REG-50153462-20240908N; 1.00 Unidad PRODUCTO; EXCAVADORA HIDRAULICA SOBRE ORUGAS, MARCA; SANY, MO DELO; SY60C(G4), REFERENCIA; SY60C, SERIAL; SY006CE1001K8, SERIAL MOTOR; 4JG3-690971, USO O DESTINO; CONSTRUCCI¿N, A¿O FABRICACI¿N; 2024;
#  Marca: SANY
#  Marca probable: SANY
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 11:
#  Descripción: DECLARACION 1 DE 2. PRODUCTO: EXCAVADORA HIDRAULICA MONTADA SOBRE ORUGAS, MARCA: CATERPILLAR, MOD: 320CL, REF: N/A, SERI
#  Marca: CATERPILLAR
#  Marca probable: CATERPILLAR
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 12:
#  Descripción: DECLARACION 2 DE 2. PRODUCTO: EXCAVADORA HIDRAULICA MONTADA SOBRE ORUGAS, MARCA: CATERPILLAR, MOD: 320CL, REF: N/A, SERIAL: CAT0320CCBRX01202, USO O DESTINO: CONSTRUCCION / INDUSTRIAL / OBRAS CIVILES. CERTIFICADO FITOSANITARI O PARA NACIONALIZACION No. CFN-8-008198-24 DE FECHA 05-SEP-2024. MERCANCIA USADA, A¿O DE FABRICACION: 2020, PRECIO CUANDO NUEVA USD: 35.000,00 (CANT. 1 UND) // PRODUCTO: EXCAVADORA HIDRAULICA MONTADA SOBRE ORUGAS, MARCA: HITA CHI, MOD: ZX200, REF: N/A, SERIAL: HHEAWJ00V00102815, USO O DESTINO: CONSTRUCCION / INDUSTRIAL / OBRAS CIVILES. CERTIFICADO FITOSANITARIO PARA NACIONALIZACION No. CFN-8-008198-24 DE FECHA 05-SEP-2024. MERCANCIA USADA, A¿O DE FABRICACION: 2020, PRECIO CUANDO NUEVA USD: 35.000,00. SE ANEXA INFORME DE RESULTADOS DE INSPECCION PREVIA No. 3502242025001 DE FECHA 03-ENE-2025, COMO CONSTANCIA DE ERROR EN EL MODELO RELACIONADO EN EL BL, PARA DAR CUMPLIMIE NTO A LO ESTABLECIDO EN EL ARTICULO 52 DEL DECRETO 1165 DE 2019. (CANT. 1 UND)**
#  Marca: CATERPILLAR, HITA CHI
#  Marca probable: CATERPILLAR, HITA CHI
#  Condición: USADO
# ------------------------------------------------------------
#
# Fila 13:
#  Descripción: DIM 4/4 DO. 3524-0595. . MERCANCIA NUEVA. PRODUCTO : CUCHARA EXCAVADORA, MARCA:RSBM, REFERENCIA / MODELO:NO TIENE, SERIAL:SIN SERIAL, USO O DESTINO: PARA RETROEXCAVADORA HIDRAULICA CANTIDAD:1(PCS)*/* PRODUCTO : CUCHARA EXCAVADORA, MARCA:RSBM, REFERENCIA / MODELO:NO TIENE, SERIAL:SIN SERIAL, USO O DESTINO: PARA RETROEXCAVADORA HIDRAULICA CANTIDAD:1(PCS)*/*
#  Marca: RSBM
#  Marca probable: RSBM
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 14:
#  Descripción: C¿DIGO OEA IMPORTADOR NO: OE0374 DO: M0303705MDE-CLO PEDIDO NRO MH00146 DECLARACION 1 DE 2 NRO. FACTURA CV24JAS0116004 - 29/10/2024 - - ITEM NRO 1 N¿MERO DE CHASIS/NUMERO VIN / SERIAL: HHKHWL50LL0001006, NUMERO DE MOTOR: 22663238, MODELO/L¿NEA/REFERENCIA: HL955A, PRODUCTO: CARGADOR FRONTAL, MARCA: HYUNDAI, MODELO: 2025, COLOR: AMARILLO, USO O DESTINO: PARA USO EN CONSTRUCCION // INCLUYE PARTES Y ACCESORIOS PARA CORRECTO ENSAMBLE Y NORMAL FUNCIONAMIENTO// PAIS DE ORIGEN COREA DEL SUR REPUB,CODIGO PAIS : 19 0 - CANTIDAD 1 - UNIDADES . . .
#  Marca: HYUNDAI
#  Marca probable: HYUNDAI
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 15:
#  Descripción: C¿DIGO OEA IMPORTADOR NO: OE0374 DO: M0303705MDE-CLO PEDIDO NRO MH00146 DECLARACION 2 DE 2 NRO. FACTURA CV24JAS0116004 - 29/10/2024 - - ITEM NRO 2 N¿MERO DE CHASIS/NUMERO VIN / SERIAL: HHKHWL50CL0001009, N¿MERO DE MOTOR: 22662858, MODELO/L¿NEA/REFERENCIA: HL955A, PRODUCTO: CARGADOR FRONTAL, MARCA: HYUNDAI, MODELO: 2025, COLOR: AMARILLO, USO O DESTINO: PARA USO EN CONSTRUCCION // INCLUYE PARTES Y ACCESORIOS PARA CORRECTO ENSAMBLE Y NORMAL FUNCIONAMIENTO// PAIS DE ORIGEN COREA DEL SUR REPUB,CODIGO PAIS : 19 0 - CANTIDAD 1 - UNIDADES . . .
#  Marca: HYUNDAI
#  Marca probable: HYUNDAI
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 16:
#  Descripción: DO 2501817 CODIGO / RESOLUCION OEA IMPORTADOR: 001927 25/03/2021; PEDIDO TRAMITE: HLCUMA3241022235 005 DECLARACION(1-1) MERCANCIA UBICADA EN ZONA FRANCA DE LA CANDELARIA CARTAGENA COLOMBIA. PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERE NCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SERIAL: CAT0236DER4D00808, INFORMACION ADICIONAL SERIAL MOTOR: J3410544, MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 4). FACTURA: 99452996 FECHA: 2024-11-11 PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERENCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SERIAL: CAT0236DAR4D00805, INFORMACION ADICIONAL SERIAL MOTOR: J3410487, MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 2). FACTURA: 99452997 FECHA: 2024-11-11 PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERENCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SERIAL: CAT0236DLR4D00806, INFORMACION ADICIONAL SERIAL MOTOR: J34105 03, MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 1). FACTURA: 99452998 FECHA: 2024-11-11 PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERENCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SER IAL: CAT0236DHR4D00807, INFORMACION ADICIONAL SERIAL MOTOR: J3410524, MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 3). MERCANCIA NUEVA. // ORDEN NUMERO: OC-000133559, OC-000133558, OC-000133552, OC-000133557 // ID: GM00009063, GM00009062, GM00009056, GM00009061 // NUMERO DE MANIFIESTO: 116575015124053 CON FECHA DEL 2024-12-28 // FORMULARIO DE INGRESO: 918802007 CON FECHA DEL 2025-01-07 // NACIONALIZACION TOTAL BL NUMERO: HLCUMA3241022235 //
#  Marca: CATERPILLAR
#  Marca probable: CATERPILLAR
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 17:
#  Descripción: DO 24120638 CODIGO / RESOLUCION OEA IMPORTADOR: 001927 25/03/2021; PEDIDO TRAMITE: CNSAC2411099 DECLARACION(1-1) MERCANCIA NUEVA. ORDEN NUMERO: OC-000138960 OC-000138968 OC-000138971 OC-000138967 // ID: GM00009330, GM00009331, GM00009332, GM00009333. PROD UCTO: MONTACARGAS, MARCA: TOWMOTOR, MODELO: GP25S, REFERENCIA: GP25S1/01606273, USO O DESTINO: INDUSTRIAL,UTILIZADO PARA TRANSPORTAR, REMOLCAR, EMPUJAR, APILAR, SUBIR O BAJAR DISTINTOS OBJETOS Y ELEMENTOS., SERIAL: CT54-50662, INFORMACION ADICIONAL SERIAL MOTOR: GK25-228850 CANTIDAD (1) U (ITEM 1). FACTURA: SP 1210987 FECHA: 2024-12-04 PRODUCTO: MONTACARGAS, MARCA: TOWMOTOR, MODELO: GP25S, REFERENCIA: GP25S1/01606274, USO O DESTINO: INDUSTRIAL,UTILIZADO PARA TRANSPORTAR, REMOLCAR, EMPUJAR, APILAR, SUBIR O BAJAR DISTINTOS OBJETOS Y ELEMENTOS., SERIAL: CT54-50663, INFORMACION ADICIONAL SERIAL MOTOR: GK25-228844 CANTIDAD (1) U (ITEM 2). FACTURA: SP 1210988 FECHA: 2024-12-04 PRODUCTO: MONTACARGAS, MARCA: TOWMOTOR, MODELO: GP25S, REFERENCIA: GP25S1/01606278, U SO O DESTINO: INDUSTRIAL,UTILIZADO PARA TRANSPORTAR, REMOLCAR, EMPUJAR, APILAR, SUBIR O BAJAR DISTINTOS OBJETOS Y ELEMENTOS., SERIAL: CT54-50664, INFORMACION ADICIONAL SERIAL MOTOR: GK25-228851 CANTIDAD (1) U (ITEM 3). FACTURA: SP 1210989 FECHA: 2024-12-0 4 PRODUCTO: MONTACARGAS, MARCA: TOWMOTOR, MODELO: GP25S, REFERENCIA: GP25S1/01606279, USO O DESTINO: INDUSTRIAL,UTILIZADO PARA TRANSPORTAR, REMOLCAR, EMPUJAR, APILAR, SUBIR O BAJAR DISTINTOS OBJETOS Y ELEMENTOS., SERIAL: CT54-50665, INFORMACION ADICIONAL SERIAL MOTOR: GK25-228846 CANTIDAD (1) U (ITEM 4).
#  Marca: TOWMOTOR
#  Marca probable: TOWMOTOR
#  Condición: USADO
# ------------------------------------------------------------
#
# Fila 18:
#  Descripción: DO BUN-024-25 PEDIDO PEDIDO GATO DECLARACION 1 DE 1; //FACTURA:UA20240805-CO, FECHA:05-08-2024, PRODUCTO: CARRETILLA ELEVADORA SEMIELECTRICA, MARCA: NO TIENE, MODELO: 51-KS08 EN FACTURA, REFERENCIA: NO TIENE, SERIAL: NO TIENE, USO O DESTINO: USO EXCLUSIVO EN BODEGA COMERCIALIZADORA GAD SAS, 2000 KG, CTD, CUENTA CON ACCESORIOS PARA SU NORMALFUNCIONAMIENTO CARGADOR QINA, NO FIVE 12V 10A, 13952663055, PLANOS Y CATALOGOS, SEMI ELECTRIC LIFT TRUCK, CANTIDAD: 1 UNIDAD PAIS DE ORIGEN: CHINA(215)
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 19:
#  Descripción: DO:BUNIMP-24-19597, PEDIDO ZHEJIANG SILI FACT.24SL1116206, DECLARACION 3 DE 5, FACTURA(S) 24SL1116206, // 1 SET, PRODUCTO: CARRETILLA ELEVADORA, MARCA: HELI, MODELO: EN CADA ITEM, REFERENCIA: NO TIENE, SERIAL: NO TIENE, USO O DESTINO: INDUSTRIAL, OPERAR M ATERIAL ; FORKLIFT; INFORMACION ADICIONAL:INFORMACION PLAQUETA MOTOR ELECTRICO:TIPO DEBATERIA: LIFEP04, TENSION NOMINAL: 80 V, NUMERO DEL PRODUCTO: HYHL-80V-280AH, NUMERO DE ELECTRICIDAD: 22,4 KWH, MODELO DE PRODUCTO: 80V/288AH, CAPACIDAD NOMINAL: 280AH, CAPACIDAD: 252 KILOS5/01/2025; INFORMACION PLAQUETA #1: MODELO DE MASTIL: ZSM450, MODELO DE ADJUNTO: LC30, ALTURA MAXIMA DE ELEVACION: 4500 MM, INFORMACION PLAQUETA #2:MODELO: CPD, CAPACIDAD DE ELEVACION NOMINAL: 3000 KG, TENSION NOMINAL: 80 V, PESO DE LA BATERIA (MINIMO): 185 KILOS, PESO DE LA BATERIA (MAXIMO): 460 KG, NUMERO DE CONFIGURACION: 30-A16LIH2, NUMERO DE PRODUCTO: 050309DG386, CON PARTES Y ACCESORIOS PARA SU NORMAL FUNCIONAMIENTO. PAIS DE ORIGEN: CHINA(215)
#  Marca: HELI
#  Marca probable: HELI
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 20:
#  Descripción: DO BAQ2024I01845 // PEDIDO IMP 120-2024 // DECLARACION 1/1 // IMPORTACION TEMPORAL A LARGO PLAZO PARA REEXPORTACION EN EL MISMO ESTADO DE CONFORMIDAD CON LO DISPUESTO EN EL NUMERAL 2) DEL ARTICULO 201, 204, 205, 207, 208 Y 21 4 DEL DECRETO 1165 DE 2019, EN CONCORDANCIA CON LOS ARTICULOS 34, 233 Y 234 DE LA RESOLUCION NO 000046 DE 2019 Y DEMAS NORMASQUE LAS MODIFIQUEN // / IMPORTACION TEMPORAL A LARGO PLAZO DE 5 ANOS LAS CUOTAS SE PAGAR¿N POR SEMES TRE VENCIDO IGUAL ES DE CONFORMIDAD CON EL ARTICULO 203 DEL DECRETO 1165/2019 ARANCEL DEL 0% DE ACUERDO AL 1881 DE 2021 Y DECRETO 272 DE 2018, IVA DEL 19%: USD 22,826.07- TOTAL A PAGAR CUOTA USD 2,282.61 // PRODUCTO: MONTACA RGAS DE 18,000 LBS, MARCA: TAYLOR MACHINE WORKS INC, LOGO TAYLOR, REFERENCIA: P50299, MODELO : GT180, SERIAL: XGT1318D-0748-10034KF, USO O DESTINO: LOGISTICA, INDUSTRIAL, AGRICULTURA,    INFO ADICIONAL: NO. SERIE MASTIL: 4800 S8012 4111 KF, NO. SERIE MOTOR: 13107596, MARCA DEL MOTOR: DEUTZ,   INFO SEGUN FACTURA: DEUTZ TD3.6 L4 TIER 4 FINAL DIESEL ENGINE, SERIAL NUMBER 13107596, STANDARD LIMITED WARRANTY TMW-057 PNEUMATIC DUEL DRIVE-8.25 X 15 18 PLY PNEUMATIC-STEER 8.25 X 15 18 PLY FULL SUSPENSION VINYL SEAT W/ADJ BACKREST (LEVER) DOUBLE AUXILIARY VALVE FOR 4 HOSES; MAST SERIAL # 4800 S8012 4111 K F; 189 MAST (MAST FORK HEIGHT) SHAFT TYPE 80 WIDE 47 LOMG X 7 WIDE X 2.75 THICK STANDARD PAINT RED CENTRIFUGAL (CENTRI) PRE-CLEANER BLU FLOOR SPOT FRONT LED LIGHT-DIRECTIONAL (FWD) ACTIVATED BLUE FLOOR SPOT REAR LED LIGHT-DIRECTIONAL (REV) ACTIVATED REAR WORK LIGHT(LED) (GT-135-180) TWO LED HEADLIOHTS (OHG MOUNTED) (IN LIEU OF STANDARD HALOGEN HEADLIGHTS) TWO UPRIGHT MOUNTED WORXLIGHTS (LED) SIDE-SHIFT AND FORK POSITIONER FOR STD UPRIGHT (SUMULTANEOUS FORK MOVEMENT HOSE ADAPTATION DOUBLE HOSE FOR STANDA RD UPRIGHT 4 HOSES INTERNAL FRONY FENDER MUD FLAPS, ONE LITER ACCUMULATOR (UPRIGHT MOUNTED) OPERATOR CAB WIH HEAT, DEFROST AND AIR CONDITIONING. REAR MOUNTED ROOF MO UNT A/C: FORK NUMBER GT0490 GT0489, 3073019; FIRE EXTINGUI SHER ACC PKG., MONTACARGA NUEVO, CON CAPACIDAD PARA 18.000 LBS, A¿O DE FABRICACION 2024. CANTIDAD: 1 UNIDAD
#  Marca: TAYLOR MACHINE WORKS INC
#  Marca probable: TAYLOR MACHINE WORKS INC
#  Condición: NUEVO
# ------------------------------------------------------------
#  Procesadas 20/30 filas...
#
#
# Fila 21:
#  Descripción: DO GRUPO-24185CTG, Pedido 2024-01759, Formato 1 de 1; Factura(s)...0007-3364 28/11/2023; MERCANCIA NUEVA Y DE PRIMERA CALIDAD, MERCANCIA AMPARADA CON REGISTRO DE IMPORTACION No. REG-50145605-20240828N & VANLA-24-18424; 1.00 U nidad PRODUCTO; RETROEXCAVADORA, MARCA; CASE, MODELO; 851 FX-4WD, REFERENCIA; 851 FX-4WD, SERIAL; NKJ851FXPPKH36936, SERIAL MOTOR; 000674737, USO O DESTINO; INDUSTRIAL, A¿O DE FABRICACION; 2023.
#  Marca: CASE
#  Marca probable: CASE
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 22:
#  Descripción: DO NO.2501-0016650 DIM 9/14 .Producto= CARRETILLA APILADORA, Marca=NOtiene.- Modelo= NO tiene.- Serial= NO tiene.- Uso o destino= APILAR MERCANCIA EN BODEGA.***/CANTIDAD= 3  .PCS .REFERENCIA= 550  ESTIBADOR MANUAL,550MM,5TON   .SIN MARCA..***/CANTIDAD= 1  .PCS .REFERENCIA= L730-3T  ESTIBADOR MANUAL ALTO,3TON ,SUBE A 2METROS  .SIN MARCA.
#  Marca: DESCONOCIDA
#  Marca probable: DESCONOCIDA
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 23:
#  Descripción: DO 2024482293 PEDIDO TRAMITE: I20309 DECLARACION(1-2) FACTURA: 202407311640 FECHA: 2024-07-31 PRODUCTO: MOTONIVELADORA RHINO RM 120, MARCA: RHINO, MODELO: RM120, REFERENCIA: 202407311640, USO O DESTINO: M¿QUINA, VEHICULO PARA CONSTRUCCION, SERIAL: RM120-P L20.1-250905, MOTONIVELADORA RHINO RM 120: Nueva. A¿o: 2025, Motor: Cummins, Color Amarillo. Maquina S/N: RM120-PL20.1-250905 y Motor S/N: 93324943 CANT (1) U (ITEM 1).
#  Marca: RHINO
#  Marca probable: RHINO
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 24:
#  Descripción: DO 2024482293 PEDIDO TRAMITE: I20309 DECLARACION(2-2) FACTURA: 202407311640 FECHA: 2024-07-31 PRODUCTO: VIBRO COMPACTADOR RHINO RC 70, MARCA: RHINO, MODELO: RC70, REFERENCIA: 202407311640, USO O DESTINO: M¿QUINA,VEHICULO PARA CONSTRUCCION, SERIAL: RC70-PL -250802, VIBRO COMPACTADOR RHINO RC 70: Nuevo. A¿o: 2025, Motor: Cummins, Color Amarillo. Maquina S/N: RC70-PL20-250802 y Motor S/N: 93280637 CANT (1) U (ITEM 2).
#  Marca: RHINO
#  Marca probable: RHINO
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 25:
#  Descripción: DECLARACION(1-1) NOS ACOGEMOS AL DECRETO 920 DE 2023 ARTICULO 29 NUMERAL 2.3.MERCANC¿A USADA A¿O DE FABRICACION 2022 .LICENCIA DE IMPORTACION LIC-40025598-20241126N; CERTIFICADO FITOSANITARIO NUMERO CFN-8-000249-25. PRODUCTO: EXCAVADORA, MARCA: HYUNDAI, MODELO: R220LC-9S, REFERENCIA: R220LC-9S, USO O DESTINO: AGRICOLA, SERIAL: HHN623HJ0003796, MODELO MOTOR: ROBEX220-9S CON TODAS SUS PARTES Y ACCESORIOS PARA SU NORMAL FUNCIONAMIENTO. CANT (1) U //
#  Marca: HYUNDAI
#  Marca probable: HYUNDAI
#  Condición: USADO
# ------------------------------------------------------------
#
# Fila 26:
#  Descripción: DO GRUPO-24818BUN ,Pedido 2024-07979 ,Formato 1 de 1; Factura(s)...0007-3428 26/02/2024;CUMPLE CON REGISTRO DE IMPORTACION No. REG-50131573-20240806N; 1.00 Unidad PRODUCTO; VIBROCOMPACTADOR SOBRE NEUMATICOS DE RODILLO SENCILLO, MARCA; XCMG, MODELO; XS45 JIV, REFERENCIA; XS45JIV,  SERIAL; XUG00453JPJQ00127, SERIAL MOTOR; C32704688A, USO O DESTINO;CONSTRUCCI¿N, A¿O FABRICACI¿N; 2024, MERCANCIA NUEVA Y DE PRIMERA CALIDAD;
#  Marca: XCMG
#  Marca probable: XCMG
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 27:
#  Descripción: DO GRUPO-24817BUN ,Pedido 2024-07978 ,Formato 1 de 1; Factura(s)...0007-3427 26/02/2024;MERCANCIA NUEVA Y DE PRIMERA CADALIDA, CUENTA CON REGISTRO DE IMPORTACION CON No; REG-50131574-20240806N, ; 1.00 Unidad PRODUCTO; VIBROCOMPACTADOR SOBRE NEUMATICOS DE RODILLO SENCILLO, MARCA; XCMG,  MODELO; XS45JIV, REFERENCIA; XS45JIV, SERIAL;XUG00453APJQ00066, SERIAL MOTOR; C32604629A, USO O DESTINO; CONSTRUCCI¿N;
#  Marca: XCMG
#  Marca probable: XCMG
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 28:
#  Descripción: DO 2501823 CODIGO / RESOLUCION OEA IMPORTADOR: 001927 25/03/2021; PEDIDO TRAMITE: HLCUMA3241022257 005 DECLARACION(1-1) MERCANCIA UBICADA EN ZONA FRANCA DE LA CANDELARIA CARTAGENA COLOMBIA. PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERE NCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SERIAL: CAT0236DHR4D00810, INFORMACION ADICIONAL SERIAL MOTOR: J3410550, ORDEN NUMERO: OC-000133555 // ID: GM00009059 MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 2). FACTURA: 99453000 FECHA: 2024-11-11 PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERENCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SERIAL: CAT0236DER4D00811, INFORMACION ADICIONAL SERIAL MOTOR: J3410553, ORDEN NUMERO: OC- 000133556 // ID: GM00009060 MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 1). FACTURA: 99453001 FECHA: 2024-11-11 PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERENCIA: 6151936, USO O DESTINO: CON STRUCCI¿N Y MINER¿A, SERIAL: CAT0236DCR4D00812, INFORMACION ADICIONAL SERIAL MOTOR: J3410564, ORDEN NUMERO: OC-000133553 // ID: GM00009057 MODELO MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 4). FACTURA: 99453002 FECHA : 2024-11-11 PRODUCTO: MINICARGADOR, MARCA: CATERPILLAR, MODELO: 236D3, REFERENCIA: 6151936, USO O DESTINO: CONSTRUCCI¿N Y MINER¿A, SERIAL: CAT0236DTR4D00813, INFORMACION ADICIONAL SERIAL MOTOR: J3410604, ORDEN NUMERO: OC-000133554 // ID: GM00009058 MODEL O MOTOR: C2.2 // CARGADOR FRONTAL // PAIS ORIGEN: INDIA - 361. CANTIDAD (1) U (ITEM 3). MERCANCIA NUEVA // NUMERO DE MANIFIESTO: 116575015124053 CON FECHA DEL 2024-12-28 // FORMULARIO DE INGRESO: 918802057 CON FECHA DEL 2025-01-09 // NACIONALIZACION TOTAL // BL NUMERO: HLCUMA3241022257 //
#  Marca: CATERPILLAR
#  Marca probable: CATERPILLAR
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 29:
#  Descripción: DO 24120641 CODIGO / RESOLUCION OEA IMPORTADOR: 001927 25/03/2021; PEDIDO TRAMITE: BR2455206 DECLARACION(1-1) MERCANCIA NUEVA.. PRODUCTO: RETROEXCAVADORA CARGADORA, MARCA: CATERPILLAR, MODELO: 416, REFERENCIA: 630-7779, USO O DESTINO: INDUSTRIAL, FUERA DE CARRETERA, MINERIA, CONSTRUCCION, SERIAL: CAT00416AH9P00334, INFORMACION ADICIONAL SERIAL MOTOR: HC703823, ORDEN NUMERO: OC-000151196// ID: GM00009974 MODELO MOTOR: C3.6 // PAIS ORIGEN: BRASIL - 105. CANTIDAD (1) U (ITEM 1).
#  Marca: CATERPILLAR
#  Marca probable: CATERPILLAR
#  Condición: NUEVO
# ------------------------------------------------------------
#
# Fila 30:
#  Descripción: DO 24120637 CODIGO / RESOLUCION OEA IMPORTADOR: 001927 25/03/2021; PEDIDO TRAMITE: BR2456308 DECLARACION(1-1) MERCANCIA NUEVA.. PRODUCTO: RETROEXCAVADORA CARGADORA, MARCA: CATERPILLAR, MODELO: 416, REFERENCIA: 630-7779, USO O DESTINO: INDUSTRIAL, FUERA DE CARRETERA, MINERIA, CONSTRUCCION, SERIAL: CAT00416VH9P00347, INFORMACION ADICIONAL SERIAL MOTOR: HC703815, MODELO MOTOR: C3.6 // PAIS ORIGEN: BRASIL - 105. CANTIDAD (1) U(ITEM 3). FACTURA: ZQG 135674 FECHA: 2024-12-05 PRODUCTO: RETROEXCAVADORA CARGADORA, MARCA: CATERPILLAR, MODELO: 416, REFERENCIA: 630-7779, USO O DESTINO: INDUSTRIAL, FUERA DE CARRETERA, MINERIA, CONSTRUCCION, SERIAL: CAT00416LH9P00335, INFORMACION ADICIONAL SERIAL MOTOR: HC703991, MODELO MOTOR: C3.6// PAIS ORIGEN: BRASIL - 105. CANTIDAD (1) U (ITEM 1). FACTURA: ZQG 135700 FECHA: 2024-12-11 PRODUCTO: RETROEXCAVADORA CARGADORA, MARCA: CATERPILLAR, MODELO: 416, REFERENCIA: 630-7779, USO O DESTINO: INDUSTRIAL, FUERA DE CARRETERA, MINERIA, CONSTRUCCION, SERIAL: CAT00416CH9P00346, INFORMACION ADICIONAL SERIAL MOTOR: HC703818, MODELO MOTOR: C3.6 // PAIS ORIGEN: BRASIL - 105. CANTIDAD (1) U (ITEM 2). ORDEN NUMERO: OC-000151198 // OC-000151184 //OC-000151197 // ID GM00009976 //GM00009973 // GM00009975
#  Marca: CATERPILLAR
#  Marca probable: CATERPILLAR
#  Condición: NUEVO
# ------------------------------------------------------------
#
#  Archivo generado: productos_clasificados.xlsx
